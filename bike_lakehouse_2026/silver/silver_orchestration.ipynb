# %% [markdown]
# #This will be our silver orchestration layer

# %%
dbutils.notebook.run("/Workspace/Users/mudzananiwavhudi7@gmail.com/first_pipeline_databricks/bike_lakehouse_2026/silver/silver_crm_cust_info",60,{})
dbutils.notebook.run("/Workspace/Users/mudzananiwavhudi7@gmail.com/first_pipeline_databricks/bike_lakehouse_2026/silver/silver_crm_prd_info",60,{})
dbutils.notebook.run("/Workspace/Users/mudzananiwavhudi7@gmail.com/first_pipeline_databricks/bike_lakehouse_2026/silver/silver_crm_sales_details",60,{})
dbutils.notebook.run("/Workspace/Users/mudzananiwavhudi7@gmail.com/first_pipeline_databricks/bike_lakehouse_2026/silver/silver_erp_cust_az12",60,{})
dbutils.notebook.run("/Workspace/Users/mudzananiwavhudi7@gmail.com/first_pipeline_databricks/bike_lakehouse_2026/silver/silver_erp_loc_a101",60,{})
dbutils.notebook.run("/Workspace/Users/mudzananiwavhudi7@gmail.com/first_pipeline_databricks/bike_lakehouse_2026/silver/silver_erp_px_cat",60,{})
