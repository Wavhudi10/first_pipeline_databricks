# %% [markdown]
# #Gold Orchestration layer

# %%
dbutils.notebook.run("/Workspace/Users/mudzananiwavhudi7@gmail.com/first_pipeline_databricks/bike_lakehouse_2026/gold/dim_customers",60,{})
dbutils.notebook.run("/Workspace/Users/mudzananiwavhudi7@gmail.com/first_pipeline_databricks/bike_lakehouse_2026/gold/dim_products",60,{})
dbutils.notebook.run("/Workspace/Users/mudzananiwavhudi7@gmail.com/first_pipeline_databricks/bike_lakehouse_2026/gold/fact_sales",60,{})
