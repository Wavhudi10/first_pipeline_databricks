# %% [markdown]
# #Initialization of my files

# %%
from bronze_config import INGESTION_CONFIG

# %%
# %sql
USE CATALOG workspace;
USE SCHEMA bronze;

# %% [markdown]
# #Reading from the CSV file and Write to Silver table

# %%
for item in INGESTION_CONFIG:
    print(f"Ingesting {item['source']} -> workspace.bronze.{item['table']}")
    df = (
        spark.read.option("header", "true")
        .option("inferSchema", "true")
        .csv(item['path'])
    )

    (
        df.write
        .mode("overwrite")
        .format("delta")
        .saveAsTable(f"workspace.bronze.{item['table']}")
    )
